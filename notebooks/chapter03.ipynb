# %% [markdown]
# # Chapter 03 — 分岐
#
# 引数を変えながらセルを実行し、分岐の動作を確認しましょう。
#
# > ⚠️ `Throw New NotImplementedException` のままの問題は実行するとエラーになります。先に実装してから試しましょう。

# %%
#load "../src/Chapter03/Exercises.vb"

# %% [markdown]
# ## 問題 3-1 〜 3-4: 大小比較（x, y を変えて試してみよう）

# %%
Dim x As Integer = 10   ' ← 変えて試そう
Dim y As Integer = 5    ' ← 変えて試そう
Console.WriteLine($"3-1: {Exercises.Problem3_1(x, y)}")
Console.WriteLine($"3-2: {Exercises.Problem3_2(x, y)}")
Console.WriteLine($"3-3 大きい方: {Exercises.Problem3_3(x, y)}")
Console.WriteLine($"3-4: {Exercises.Problem3_4(x, y)}")

# %% [markdown]
# ## 問題 3-5 〜 3-6: 偶数・奇数の分類（x を変えて試してみよう）

# %%
Dim x As Integer = -4   ' ← 変えて試そう（0 や負の数も試してみよう）
Console.WriteLine($"3-5: {Exercises.Problem3_5(x)}")
Console.WriteLine($"3-6: {Exercises.Problem3_6(x)}")

# %% [markdown]
# ## 問題 3-7: 成績判定（score を変えて試してみよう）
#
# 境界値（59, 60, 69, 70, 79, 80）で結果が変わることを確認してみましょう。

# %%
Dim score As Integer = 75   ' ← 変えて試そう
Console.WriteLine($"ケース1: {Exercises.Problem3_7_Case1(score)}")
Console.WriteLine($"ケース2: {Exercises.Problem3_7_Case2(score)}")
Console.WriteLine($"ケース3: {Exercises.Problem3_7_Case3(score)}")

# %% [markdown]
# ## 問題 3-8: 合否判定（midterm, final を変えて試してみよう）
#
# 3 つの合格条件を満たすパターンをそれぞれ試してみましょう。

# %%
Dim midterm As Integer = 50   ' ← 変えて試そう
Dim final As Integer = 90     ' ← 変えて試そう
Console.WriteLine($"中間:{midterm} 期末:{final} → {Exercises.Problem3_8(midterm, final)}")

# %% [markdown]
# ## 問題 3-9: 病院の診察時間（曜日と時間帯を変えて試してみよう）
#
# 曜日: 0=日, 1=月, 2=火, 3=水, 4=木, 5=金, 6=土
# 時間帯: 0=午前, 1=午後, 2=夜間

# %%
' 全曜日・全時間帯の一覧を表示する
Dim days = {"日", "月", "火", "水", "木", "金", "土"}
Dim times = {"午前", "午後", "夜間"}
Console.Write("     ")
For Each d In days
    Console.Write($"{d}  ")
Next
Console.WriteLine()
For t = 0 To 2
    Console.Write($"{times(t)} ")
    For d = 0 To 6
        Console.Write($"{Exercises.Problem3_9(d, t)}  ")
    Next
    Console.WriteLine()
Next

# %% [markdown]
# ## 問題 3-11: 寿司占い（choice を 1〜5 で試してみよう）

# %%
Dim choice As Integer = 1   ' ← 1〜5 で変えて試そう
Console.WriteLine(Exercises.Problem3_11(choice))

# %% [markdown]
# ## 問題 3-12: 大の月・小の月（month を 1〜13 で試してみよう）

# %%
' 全月まとめて確認
For month = 1 To 12
    Console.WriteLine(Exercises.Problem3_12(month))
Next
Console.WriteLine(Exercises.Problem3_12(13))
