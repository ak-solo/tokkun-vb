# %% [markdown]
# # Chapter 05 — 配列
#
# 引数を変えながらセルを実行し、配列操作の動作を確認しましょう。
#
# > ⚠️ `Throw New NotImplementedException` のままの問題は実行するとエラーになります。先に実装してから試しましょう。

# %%
#load "../src/Chapter05/Exercises.vb"

# %% [markdown]
# ## 問題 5-1 〜 5-2: 2 倍・逆順（numbers を変えて試してみよう）

# %%
Dim numbers As Integer() = {3, 7, 1, 9, 4}   ' ← 変えて試そう
Console.WriteLine($"元: {String.Join(", ", numbers)}")
Console.WriteLine($"2倍: {String.Join(", ", Exercises.Problem5_1(numbers))}")
Console.WriteLine($"逆順: {String.Join(", ", Exercises.Problem5_2(numbers))}")

# %% [markdown]
# ## 問題 5-3: 偶数・奇数の分類

# %%
Dim numbers As Integer() = {42, 7, 54, 35, 71, 13, 21, 45, 32, 8}   ' ← 変えて試そう
Dim result = Exercises.Problem5_3(numbers)
Console.WriteLine($"偶数: {String.Join(" ", result(0))}")
Console.WriteLine($"奇数: {String.Join(" ", result(1))}")

# %% [markdown]
# ## 問題 5-5: 2 進数変換（value を変えて試してみよう）

# %%
Dim value As Integer = 42   ' ← 変えて試そう（0〜65535）
Dim binary = Exercises.Problem5_5(value)
Console.WriteLine($"{value} = {String.Join("", binary)}")

# %% [markdown]
# ## 問題 5-6: 九九表の表示

# %%
Dim kuku = Exercises.Problem5_6()
For i = 0 To 8
    For j = 0 To 8
        Console.Write($"{kuku(i, j),3}")
    Next
    Console.WriteLine()
Next

# %% [markdown]
# ## 問題 5-7: 九九配列を使った積の計算（x, y を変えて試してみよう）

# %%
Dim x As Integer = 7   ' ← 1〜9 で変えて試そう
Dim y As Integer = 8   ' ← 1〜9 で変えて試そう
Console.WriteLine($"{x} × {y} = {Exercises.Problem5_7(x, y)}")

# %% [markdown]
# ## 問題 5-8: ソート（numbers を変えて試してみよう）
#
# 元の配列が変更されないことも確認してみましょう。

# %%
Dim numbers As Integer() = {5, 3, 8, 1, 9, 2, 7, 4, 6, 0}   ' ← 変えて試そう
Dim sorted = Exercises.Problem5_8(numbers)
Console.WriteLine($"元:   {String.Join(", ", numbers)}")
Console.WriteLine($"並替: {String.Join(", ", sorted)}")
