# %% [markdown]
# # Chapter 02 — 引数と戻り値
#
# 引数の値を変えながらセルを実行し、関数の動作を確認しましょう。
#
# > ⚠️ `Throw New NotImplementedException` のままの問題は実行するとエラーになります。先に実装してから試しましょう。

# %%
#load "../src/Chapter02/Exercises.vb"

# %% [markdown]
# ## 問題 2-1 〜 2-2: 引数をそのまま返す

# %%
Dim s As String = "Hello VB.NET"   ' ← 変えて試そう
Console.WriteLine(Exercises.Problem2_1(s))

Dim x As Integer = 42              ' ← 変えて試そう
Console.WriteLine(Exercises.Problem2_2(x))

# %% [markdown]
# ## 問題 2-3: 累乗（x の値を変えて試してみよう）

# %%
Dim x As Integer = 3   ' ← 変えて試そう
Dim result = Exercises.Problem2_3(x)
Console.WriteLine($"{x} の 1 乗: {result(0)}")
Console.WriteLine($"{x} の 2 乗: {result(1)}")
Console.WriteLine($"{x} の 3 乗: {result(2)}")

# %% [markdown]
# ## 問題 2-4: 四則演算まとめ（x, y の値を変えて試してみよう）

# %%
Dim x As Integer = 10   ' ← 変えて試そう
Dim y As Integer = 3    ' ← 変えて試そう
Console.WriteLine($"和      : {Exercises.Problem2_4_Sum(x, y)}")
Console.WriteLine($"差(x-y) : {Exercises.Problem2_4_Difference(x, y)}")
Console.WriteLine($"積      : {Exercises.Problem2_4_Product(x, y)}")
Console.WriteLine($"除算    : {Exercises.Problem2_4_Division(x, y)}")
Console.WriteLine($"商      : {Exercises.Problem2_4_Quotient(x, y)}")
Console.WriteLine($"余り    : {Exercises.Problem2_4_Remainder(x, y)}")

# %% [markdown]
# ## 問題 2-5: 平均値（a, b の値を変えて試してみよう）
#
# 合計が奇数のとき、小数が切り捨てられることを確認してみましょう。

# %%
Dim a As Integer = 3    ' ← 変えて試そう
Dim b As Integer = 4    ' ← 変えて試そう
Console.WriteLine($"{a} と {b} の平均: {Exercises.Problem2_5(a, b)}")

# %% [markdown]
# ## 問題 2-6: 年齢から日数を計算（age の値を変えて試してみよう）

# %%
Dim age As Integer = 20   ' ← 変えて試そう
Console.WriteLine($"年齢 {age} 歳 → おおよそ {Exercises.Problem2_6(age)} 日")
