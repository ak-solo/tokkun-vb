# %% [markdown]
# # Chapter 04 — 繰り返し
#
# 引数を変えながらセルを実行し、ループ処理の動作を確認しましょう。
#
# > ⚠️ `Throw New NotImplementedException` のままの問題は実行するとエラーになります。先に実装してから試しましょう。

# %%
#load "../src/Chapter04/Exercises.vb"

# %% [markdown]
# ## 問題 4-1 〜 4-4: 固定回数のループ

# %%
' 4-1: SPAM を 10 回
For Each s In Exercises.Problem4_1()
    Console.Write(s & " ")
Next
Console.WriteLine()

' 4-2: 三の段
Console.WriteLine(String.Join(", ", Exercises.Problem4_2()))

' 4-3: 2 の累乗
Console.WriteLine(String.Join(", ", Exercises.Problem4_3()))

' 4-4: 7!
Console.WriteLine($"7! = {Exercises.Problem4_4()}")

# %% [markdown]
# ## 問題 4-15: 素因数分解（n の値を変えて試してみよう）

# %%
Dim n As Integer = 20100   ' ← 変えて試そう（2 以上）
Console.WriteLine($"{n} = {String.Join(" × ", Exercises.Problem4_15(n))}")

# %% [markdown]
# ## 問題 4-16: 素数判定（n の値を変えて試してみよう）

# %%
Dim n As Integer = 97   ' ← 変えて試そう
Console.WriteLine($"{n} は素数か: {Exercises.Problem4_16(n)}")

' 100 以下の素数を全部探す
Console.Write("100 以下の素数: ")
For i = 2 To 100
    If Exercises.Problem4_16(i) Then Console.Write($"{i} ")
Next

# %% [markdown]
# ## 問題 4-17: 九九表

# %%
Dim kuku = Exercises.Problem4_17()
For i = 0 To 8
    For j = 0 To 8
        Console.Write($"{kuku(i, j),3}")
    Next
    Console.WriteLine()
Next

# %% [markdown]
# ## 問題 4-20: 三角形（size を変えて試してみよう）

# %%
Dim size As Integer = 5   ' ← 変えて試そう
For Each line In Exercises.Problem4_20(size)
    Console.WriteLine(line)
Next

# %% [markdown]
# ## 問題 4-21: × 印（size を変えて試してみよう）

# %%
Dim size As Integer = 5   ' ← 変えて試そう（2 以上）
For Each line In Exercises.Problem4_21(size)
    Console.WriteLine(line)
Next

# %% [markdown]
# ## 問題 4-22: フィボナッチ数列（1000 以下）

# %%
Dim fib = Exercises.Problem4_22()
Console.WriteLine($"項数: {fib.Length}")
Console.WriteLine(String.Join(", ", fib))
